# %% [markdown]
# ### My first python program
# I am so happy to start learning python

# %%
print("Hello, Khushi Sharma")
print("Welcome to Indian AI Production")
print("You are started learning Python for Agentic AI Engineering")
